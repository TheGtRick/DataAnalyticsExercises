# %%
import pandas as pd
import numpy as np

# %%
portuguese_students = pd.read_csv('student_portuguese_clean.csv')
portuguese_students
# Out:
#      student_id school sex  age address_type              family_size  \
# 0             1     GP   F   18        Urban           Greater than 3
# 1             2     GP   F   17        Urban           Greater than 3
# 2             3     GP   F   15        Urban  Less than or equal to 3
# 3             4     GP   F   15        Urban           Greater than 3
# 4             5     GP   F   16        Urban           Greater than 3
# ..          ...    ...  ..  ...          ...                      ...
# 644         645     MS   F   19        Rural           Greater than 3
# 645         646     MS   F   18        Urban  Less than or equal to 3
# 646         647     MS   F   18        Urban           Greater than 3
# 647         648     MS   M   17        Urban  Less than or equal to 3
# 648         649     MS   M   18        Rural  Less than or equal to 3
#
#        parent_status               mother_education  \
# 0              Apart               higher education
# ...

# %%
math_students = pd.read_csv('student_math_clean.csv')
math_students
# Out:
#      student_id school sex  age address_type              family_size  \
# 0             1     GP   F   18        Urban           Greater than 3
# 1             2     GP   F   17        Urban           Greater than 3
# 2             3     GP   F   15        Urban  Less than or equal to 3
# 3             4     GP   F   15        Urban           Greater than 3
# 4             5     GP   F   16        Urban           Greater than 3
# ..          ...    ...  ..  ...          ...                      ...
# 390         391     MS   M   20        Urban  Less than or equal to 3
# 391         392     MS   M   17        Urban  Less than or equal to 3
# 392         393     MS   M   21        Rural           Greater than 3
# 393         394     MS   M   18        Rural  Less than or equal to 3
# 394         395     MS   M   19        Urban  Less than or equal to 3
#
#        parent_status               mother_education  \
# 0              Apart               higher education
# ...

# %% [markdown]
# # Visualization

# %% [markdown]
# 1.Histogram of Ages: Show the distribution of student ages in both schools.

# %%
#code here
import matplotlib.pyplot as plt
ages_math = math_students['age']
ages_portuguese = portuguese_students['age']

fig, axs = plt.subplots(1, 2, figsize=(12, 6))
axs[0].hist(ages_math, bins=10, color='skyblue', edgecolor='black')
axs[0].set_title('Age Distribution - Math School')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Frequency')

axs[1].hist(ages_portuguese, bins=10, color='salmon', edgecolor='black')
axs[1].set_title('Age Distribution - Portuguese School')
axs[1].set_xlabel('Age')
axs[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# 2.Bar Chart for Gender Distribution: Visualize the count of males and females in each school.

# %% [markdown]
# 3.Pie Chart for Address Types: Illustrate the proportion of urban vs. rural students.

# %% [markdown]
# 4.Box Plot for Study Time vs. Grades: Compare study time distribution with student grades for both subjects.

# %% [markdown]
# 5.Scatter Plot of Absences vs. Grades: Explore if there's a correlation between absences and grades in each subject.

# %% [markdown]
# 6.Bar Chart for Parental Education Levels: Compare the education levels of mothers and fathers in the dataset.

# %% [markdown]
# 7.Stacked Bar Chart for Family Support: Show the count of family support with respect to the course subject and school.

# %% [markdown]
# 8.Line Chart for Alcohol Consumption: Display the trend of weekday and weekend alcohol consumption across different age groups.

# %% [markdown]
# 9.Heatmap of Correlation: Generate a heatmap to visualize correlations between different attributes.

# %% [markdown]
# 10.Pairwise Scatter Plots for Study Time and Failures: Explore relationships between study time and past class failures.

# %% [markdown]
# 11.Handle Missing Values: Identify and handle missing values (if any) in the dataset.

# %% [markdown]
# 12.Encode Categorical Variables: Convert categorical variables (like 'sex', 'address_type', 'school_support', etc.) into numerical values using one-hot encoding or label encoding.

# %% [markdown]
# 13.Normalize Numeric Attributes: Normalize numeric attributes like 'absences', 'age', and 'health' to a standard scale if needed.

# %% [markdown]
# 14.Feature Engineering: Create a new feature representing total study time combining 'study_time' and 'travel_time'.

# %% [markdown]
# 15.Outlier Detection and Handling: Detect and handle outliers in numeric attributes like 'absences' or 'age'.

# %% [markdown]
# 16.Merge Datasets: Merge the math and Portuguese datasets if necessary, adding a new column to distinguish the subjects.

# %% [markdown]
# 17.Remove Redundant Features: Eliminate any irrelevant or redundant attributes that do not contribute significantly to analysis or modeling.

# %% [markdown]
# 18.Balance Class Failures: If class failures are highly imbalanced, apply techniques to balance the classes.

# %% [markdown]
# 19.Partition Data: Split the dataset into training and testing sets for predictive modeling.
